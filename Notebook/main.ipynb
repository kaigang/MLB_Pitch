# %%
import os
from matplotlib import pyplot as plt
# %pylab inline
os.chdir('/home/kaigang/Desktop/MLB/')
from Code.Pitch_Release import pitch_analysis
from Code.params import TEST_LINKS,TEST_RESIZED
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
files = TEST_RESIZED(360)

# %%
analyzer = pitch_analysis(files[3])

# %%
analyzer._run()
# Out:
# calculate optical flow from file: /home/kaigang/Desktop/MLB/Data/360/test4.mp4
# calculating ball release frame

# %%
print('at frame: %d, the pitcher released the ball' % analyzer.release_index)
# Out:
# at frame: 591, the pitcher released the ball

# %%
plt.imshow(analyzer.release_frame)

# %%
import imageio
vid = imageio.get_reader(files[3], 'ffmpeg')

# %%
plt.imshow(vid.get_data(index=analyzer.release_index))
